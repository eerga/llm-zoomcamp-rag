# %% [markdown]
# # Homework 5

# %% [markdown]
# **Part 1 — Q1, Q2, Q3**
# [homework_part1.ipynb](homework_part1.ipynb)
#
# Sets up OpenTelemetry with `ConsoleSpanExporter`, implements `RAGTraced`, and answers timing/token questions from console output.
#
# **Part 2 — Q4+ **
# [homework_part2.ipynb](homework_part2.ipynb)
#
# Fresh kernel with `SQLiteSpanExporter` wired in from the start alongside the console exporter. Runs queries and reads results from `traces.db`.
