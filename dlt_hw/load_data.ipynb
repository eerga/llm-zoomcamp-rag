# %%
PREFIX="https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/cohorts/2026/workshops/dlt/homework"

#!wget {PREFIX}/agent.py
#!wget {PREFIX}/ingest.py
#!wget {PREFIX}/main.py
#!wget {PREFIX}/.env.example -O .env
# Out:
# --2026-07-20 17:17:20--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/cohorts/2026/workshops/dlt/homework/agent.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4379 (4.3K) [text/plain]
# Saving to: ‘agent.py’
#
# agent.py            100%[===================>]   4.28K  --.-KB/s    in 0s
#
# 2026-07-20 17:17:20 (24.3 MB/s) - ‘agent.py’ saved [4379/4379]
#
# --2026-07-20 17:17:20--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/cohorts/2026/workshops/dlt/homework/ingest.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 739 [text/plain]
# Saving to: ‘ingest.py’
#
# ingest.py           100%[===================>]     739  --.-KB/s    in 0s
#
# 2026-07-20 17:17:21 (30.8 MB/s) - ‘ingest.py’ saved [739/739]
#
# --2026-07-20 17:17:21--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/cohorts/2026/workshops/dlt/homework/main.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 677 [text/plain]
# Saving to: ‘main.py’
#
# main.py             100%[===================>]     677  --.-KB/s    in 0s
#
# 2026-07-20 17:17:21 (23.5 MB/s) - ‘main.py’ saved [677/677]
#
# --2026-07-20 17:17:21--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/cohorts/2026/workshops/dlt/homework/.env.example
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 273 [text/plain]
# Saving to: ‘.env’
#
# .env                100%[===================>]     273  --.-KB/s    in 0s
#
# 2026-07-20 17:17:21 (10.7 MB/s) - ‘.env’ saved [273/273]

# %% [markdown]
# ## Question 1. Instrument the agent with Logfire
# Run the agent a few times with different questions and open your
# project on Logfire to see the traces.
#
# For the following query
#
# > How do I run Ollama locally?
#
# how many spans does a single agent run produce?
#
# Each span is either the agent run itself, an LLM call, or a tool call.
# The number can vary between runs because the model decides how many
# times to search.
#
# * 1
# * 5
# * 15
# * 30

# %%
import logfire
logfire.configure()
logfire.instrument_pydantic_ai()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import logfire
#       2 logfire.configure()
#       3 logfire.instrument_pydantic_ai()
#
# File /workspaces/llm-zoomcamp-rag/.venv/lib/python3.12/site-packages/logfire/__init__.py:11
#       9 from ._internal.auto_trace import AutoTraceModule
#      10 from ._internal.auto_trace.rewrite_ast import no_auto_trace
# ---> 11 from ._internal.cli import logfire_info
#      12 from ._internal.config import AdvancedOptions, CodeSource, ConsoleOptions, MetricsOptions, PydanticPlugin, configure
#      13 from ._internal.constants import LevelName
#
# File /workspaces/llm-zoomcamp-rag/.venv/lib/python3.12/site-packages/logfire/_internal/cli.py:26
#      23 from logfire.exceptions import LogfireConfigError
#      24 from logfire.propagate import ContextCarrier, get_context
# ---> 26 from ..version import VERSION
#      27 from .auth import DEFAULT_FILE, HOME_LOGFIRE, DefaultFile, is_logged_in, poll_for_token, request_device_code
#      28 from .config import LogfireCredentials
#
# File /workspaces/llm-zoomcamp-rag/.venv/lib/python3.12/site-packages/logfire/version.py:3
#       1 """Version information for logfire package."""
# ----> 3 import importlib_metadata
#       5 VERSION = importlib_metadata.version('logfire')
#
# ModuleNotFoundError: No module named 'importlib_metadata'
